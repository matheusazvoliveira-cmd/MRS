# %%
import os, re, json, warnings
import geopandas as gpd
import pandas as pd
from shapely.geometry import box

warnings.filterwarnings("ignore", category=UserWarning)

ESTACOES_SHP = r"C:\Users\matheus.deoliveira\OneDrive - Wabtec Corporation\Matheus\wabtec\Advanced Technology\MRS\Malha Ferroviária Federal (shp)\Malha Ferroviária Federal (shp)\Estacoes Code\Estacoes\Estacoes.shp"
LINHAS_SHP   = r"C:\Users\matheus.deoliveira\OneDrive - Wabtec Corporation\Matheus\wabtec\Advanced Technology\MRS\Malha Ferroviária Federal (shp)\Malha Ferroviária Federal (shp)\Estacoes Code\Linhas\CLinhas_BR.shp"
OUTDIR       = r"saida_mrs"
os.makedirs(OUTDIR, exist_ok=True)

# Agora já sabemos:
STATION_NAME_FIELD = "NomeEstaca"
MRS_CODE = 11.0

# %%
est_raw = gpd.read_file(ESTACOES_SHP)
lin_raw = gpd.read_file(LINHAS_SHP)

print("Estacoes colunas:", list(est_raw.columns))
print("Linhas colunas:  ", list(lin_raw.columns))
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[10], line 2
#       1 est_raw = gpd.read_file(ESTACOES_SHP)
# ----> 2 lin_raw = gpd.read_file(LINHAS_SHP)
#       4 print("Estacoes colunas:", list(est_raw.columns))
#       5 print("Linhas colunas:  ", list(lin_raw.columns))
#
# File c:\Users\matheus.deoliveira\AppData\Local\Programs\Python\Python313\Lib\site-packages\geopandas\io\file.py:317, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     314             filename = response.read()
#     316 if engine == "pyogrio":
# --> 317     return _read_file_pyogrio(
#     318         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     319     )
#     321 elif engine == "fiona":
#     322     if pd.api.types.is_file_like(filename):
#
# ...
